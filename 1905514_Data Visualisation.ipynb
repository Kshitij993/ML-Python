# %% [markdown]
# # Data Visualisation

# %% [markdown]
#  * Name : Kshitij Kumar Sharma
#  * Roll No: 1905514
#  * Date: 30/03/2022

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=[1,2,3,4,5,6]
y=[i**2 for i in x]
plt.plot(x,y)

# %%
x=range(-100,100,10)
y1=[i**2 for i in x]
y2=[-i**2 for i in x]

plt.plot(x,y1)

# %%
plt.plot(x,y2)

# %%
x=range(-100,100,10)
y1=[i**2 for i in x]
y2=[-i**2 for i in x]

plt.plot(x,y1)
plt.plot(x,y2)


plt.xlabel("X")
plt.ylabel("Y")

plt.ylim(-2000,2000)     #limit 

plt.axhline(0)           #horizontal line at 0

plt.axvline(0)

#plt.savefig("test.png")   to save the fig

plt.show()

# %% [markdown]
# ## Line Plot

# %%
year=[2015,2016,2017,2018,2019]
s1=[90,92,94,95,97]
s2=[89,91,93,95,98]
plt.plot(year,s1,color='g')
plt.plot(year,s2,color='orange')
plt.xlabel("Year")
plt.ylabel("Pass Percentage")
plt.title("Pass % comparison ")
plt.show()

# %% [markdown]
# ## Pie Plot

# %%
labels = ['Candidate1', 'Candidate2', 'Candidate3', 'Candidate4']  
votes = [315, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']  
explode = (0.1, 0, 0, 0)    # explode 1st slice
plt.pie(votes, explode=explode, labels=labels, colors=colors,  autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Bar Graph

# %%
label = ['Anil', 'Vikas', 'Dharma', 'Mahen',  'Manish', 'Rajesh']
per = [94,85,45,25,50,54]

index = np.arange(len(label))  

plt.bar(index, per)

plt.xlabel('Student Name', fontsize=5)  
plt.ylabel('Percentage', fontsize=5)  

plt.xticks(index, label, fontsize=5,  rotation=30)

plt.title('Percentage of Marks achieve by  student Class XII')

plt.show()

# %%
label = ['Anil', 'Vikas', 'Dharma', 'Mahen',  'Manish', 'Rajesh']
per = [94,85,45,25,50,54]

index = np.arange(len(label))  

plt.barh(index, per)

plt.xlabel('Student Name', fontsize=5)  
plt.ylabel('Percentage', fontsize=5)  

plt.yticks(index, label, fontsize=5,  rotation=30)

plt.title('Percentage of Marks achieve by  student Class XII')

plt.show()

# %% [markdown]
# ## Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x,edgecolor='r')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt  
data = [1,11,21,31,41]
plt.hist([5,15,25,35,15,45,55],bins=[0,10,20,30,40,50,60],weights=[20,10,45,33,6,8,10])
#plt.hist(data, bins=20, histtype='step')  
plt.xlabel('Value')  
plt.ylabel('Probability')  
plt.title('Histogram')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt  
data = [1,11,21,31,41]
plt.hist([5,15,25,35,15, 55],bins=[0,10,20,30,40,50, 60],weights=[20,10,45,33,6,8],edgecolor="red")  
#plt.hist(data, bins=20, histtype='step')  
plt.xlabel('Value')  
plt.ylabel('Probability')  
plt.title('Histogram')
plt.show()

# %% [markdown]
# ## Frequency Polygon

# %%
import numpy as np
import matplotlib.pyplot as plt  
data = [1,11,21,31,41]
plt.hist([5,15,25,35,15, 55],bins=[0,10,20,30,40,50, 60],weights=[20,10,45,33,6,8],edgecolor="red",histtype='step')  
plt.xlabel('Value')  
plt.ylabel('Probability')  
plt.title('Histogram')
plt.show()

# %% [markdown]
# ## Box Plot

# %%
value1 = [72,76,24,40,57,62,75,78,31,32]  
value2=[62,5,91,25,36,32,96,95,30,90]  
value3=[23,89,12,78,72,89,25,69,68,86]  
value4=[99,73,70,16,81,61,88,98,10,87]
box_plot_data=[value1,value2,value3,value4]  
box=plt.boxplot(box_plot_data,vert=1,patch_artist=True,labels=['course1','course2','course3','  course4'],)
colors = ['cyan', 'lightblue', 'lightgreen', 'tan']
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)  
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
weight1=[93.3,67,62.3,43,71,71.8]  
height1=[116.3,110.7,124.8,176.3,137.1,113.9]

plt.scatter(weight1,height1,c='b',marker='o')  
plt.xlabel('weight', fontsize=16)  
plt.ylabel('height', fontsize=16)
plt.title('scatter plot - height vs weight',fontsize=20)  
plt.show()
