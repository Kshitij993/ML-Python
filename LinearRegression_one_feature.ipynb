# %%
#importing liberaries to work 


import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np

# %%
#loading the data file which is in csv form 

df= pd.read_csv("C:\ML\FuelConsumptionCo2.csv")

# %%
#seeing the head of the data
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
df       #shows full data
# Out:
#       MODELYEAR          MAKE                        MODEL    VEHICLECLASS  \
# 0          2014         ACURA                          ILX         COMPACT
# 1          2014         ACURA                          ILX         COMPACT
# 2          2014         ACURA                   ILX HYBRID         COMPACT
# 3          2014         ACURA                      MDX 4WD     SUV - SMALL
# 4          2014         ACURA                      RDX AWD     SUV - SMALL
# 5          2014         ACURA                          RLX        MID-SIZE
# 6          2014         ACURA                           TL        MID-SIZE
# 7          2014         ACURA                       TL AWD        MID-SIZE
# 8          2014         ACURA                       TL AWD        MID-SIZE
# 9          2014         ACURA                          TSX         COMPACT
# 10         2014         ACURA                          TSX         COMPACT
# ...

# %%
df.describe()     #describes each features of the data.
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# ...

# %%
#selecting some of the features from the data

cdf=df[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2EMISSIONS']]

# %%
#plotting the graph
viz=cdf[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2EMISSIONS']]
viz.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020076AC5550>,
# ...
#       dtype=object)

# %%
#now plotting different graphs 
#graphs vs co2emission to check linear dependence

#graph of co2 emission with respect to fuel consumption

plt.scatter(cdf.FUELCONSUMPTION_COMB , cdf.CO2EMISSIONS, color='blue')
plt.xlabel('FUELCONSUMPTION_COMB')
plt.ylabel('CO2EMISSIONS')
plt.show()

# %%
#graph of co2 emission with respect to engine size

plt.scatter(cdf.ENGINESIZE , cdf.CO2EMISSIONS , color='blue')
plt.xlabel('ENGINESIZE')
plt.ylabel('CO2EMISSIONS')
plt.show()

# %%
"""""
Creating train and test dataset

Train/Test Split involves splitting the dataset into training and testing sets respectively,
which are mutually exclusive. After which, you train with the training set and test with the testing set.
This will provide a more accurate evaluation on out-of-sample accuracy because the testing dataset is not 
part of the dataset that have been used to train the data. It is more realistic for real world problems.
This means that we know the outcome of each data point in this dataset, making it great to test with! 
And since this data has not been used to train the model, the model has no knowledge of the outcome of 
these data points. So, in essence, it is truly an out-of-sample testing.
Lets split our dataset into train and test sets, 80% of the entire data for training, and the 20% for testing.
We create a mask to select random rows using np.random.rand() function:
"""""

len(df)        #gives the length of the dataframe
msk=np.random.rand(len(df))<0.8
train=cdf[msk]
test=cdf[~msk]

# %%
plt.scatter(train.ENGINESIZE , train.CO2EMISSIONS , color='blue')
plt.xlabel('ENGINESIZE')
plt.ylabel('CO2EMISSION')
plt.show()

# %%
#importing th model from sikit learn

from sklearn import linear_model
regr=linear_model.LinearRegression()               #loading the model

train_x= np.asanyarray(train[['ENGINESIZE']])      #converting to array
train_y=np.asanyarray(train[['CO2EMISSIONS']])

regr.fit(train_x,train_y)     # fitting into the model

# here Q0 and Q1 are the intercept and cofficient

print('cofficient:- ', regr.coef_)                  
print('intercept:- ', regr.intercept_)
# Out:
# cofficient:-  [[39.06530594]]
# intercept:-  [125.13187458]

# %%
# *******  now plotting the FIT line on the over the data
plt.scatter(train.ENGINESIZE, train.CO2EMISSIONS, color='blue')
plt.plot(train_x,regr.coef_[0][0]*train_x+regr.intercept_[0] , '-r')
plt.xlabel('ENGINESIZE')
plt.ylabel('CO2EMISSIONS')
plt.show()

# %%
# now checking the accuracy and score of the model

from sklearn.metrics import r2_score

#test_x= np.asanyarray(test('ENGINESIZE')
#test_y= np.asanyarray(test('CO2EMISSIONS']))

test_x= np.asanyarray(test[['ENGINESIZE']])      #converting to array
test_y=np.asanyarray(test[['CO2EMISSIONS']])

test_y_hat= regr.predict(test_x)   # predicting the values 

print('mean absolute error :-',np.mean(np.absolute(test_y_hat-test_y)))

print('residual sum of squares :-', np.mean((test_y_hat-test_y)**2))

print('R2 score :- ', r2_score(test_y_hat, test_y))    #R2 is not an error but a popular matric for accuracy of a model 

# as grater the value of r2 as better your model fits into the data , its maximum value can be 1.0 and it can be negative
# also
# Out:
# mean absolute error :- 23.4994979708906
# residual sum of squares :- 988.0069983855786
# R2 score :-  0.6655726950656115
